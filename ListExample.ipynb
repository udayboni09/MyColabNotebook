# %%
class Solution:
  def removeEvens(self,lst):
    returnLst = []
    for each in lst:
      if each%2 != 0:
        returnLst.append(each)
    return returnLst

sol = Solution()
print(sol.removeEvens(self,[1,2,4,5,10,6,3]))
# Out:
# [1, 5, 3]
