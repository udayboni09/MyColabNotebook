# %% [markdown]
# Following program is to check if the given word can be spelled using the letters of the given Magnizen
#
# magnizen = [A,B,C,D,E,F]
# word  ="BED"
#
# Approach 1: If we with brute force approach then we have to search for each character in word against each character in magnizen. This take O(N) * O(M) time complexity
#
# Approch 2:
# We can use SETS however if there are any duplicates in given magnizen then sets can't be used
#
# Approach 3:
# We can use HashMap Time Complexity would be O(M) + O(N). Space complexity would be the number of characters in HasMap which is O(26) ignoring numbers, special characters then Space Complexity would be: O(26)= O(1)

# %%
from collections import defaultdict
class Solution(object):
  def canSpell(self, magazine, note):
    letters = defaultdict(int)
    #now for each letter in magazine assing value 1 in hashmap as value 
    for c in magazine:
      letters[c] =+ 1
    print(letters)

    #now traverse each value in note and see if that is present in letters? how by checking value for that letter
    for each in note:
      if letters[each] <=0:
         #that means value is not  there in magazine 
         return False
      # when we reached here means that letter from note does exists in magazine
      letters[c] -= 1
    return True 

#Driver function
print(Solution().canSpell(['a','b','c','d','e', 'f'], "bed"))
#True
print(Solution().canSpell(['a','b','c','d','e', 'f'], "cat"))
#False
# Out:
# defaultdict(<class 'int'>, {'a': 1, 'b': 1, 'c': 1, 'd': 1, 'e': 1, 'f': 1})
# True
# defaultdict(<class 'int'>, {'a': 1, 'b': 1, 'c': 1, 'd': 1, 'e': 1, 'f': 1})
# False
