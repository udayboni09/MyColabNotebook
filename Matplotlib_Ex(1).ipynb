# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x,y, color = 'red')
plt.show()

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a line plot
plt.plot(x, y)

# Display the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y)

# Display the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.scatter(x,y, marker = '*')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Line plot
plt.plot(x, y)
plt.show()

# Scatter plot
plt.scatter(x, y)
plt.show()

# %%
# Line style and color
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
# Customize line plot with line styles, width and colors
plt.plot(x, y, marker = 'x', markercolor = 'black', linestyle='-', linewidth = 3, color='r')
# Titles, labels, and legends
plt.title('Line Chart -- relationship between x and y')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cf08fcac438a> in <cell line: 5>()
#       3 y = [2, 4, 6, 8, 10]
#       4 # Customize line plot with line styles, width and colors
# ----> 5 plt.plot(x, y, marker = 'x', markercolor = 'black', linestyle='-', linewidth = 3, color='r')
#       6 # Titles, labels, and legends
#       7 plt.title('Line Chart -- relationship between x and y')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
# Customize scatter plot with marker style and size
plt.scatter(x, y, marker='x', s = 50, color='green')
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# adding markes to line plot
plt.plot(x, y, marker = 'o', markersize = 8, markerfacecolor = 'red', markeredgecolor = 'red', color = 'blue')
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Bar plot
labels = ['A', 'B', 'C', 'D', 'E']
values = [3, 7, 5, 2, 8]
plt.bar(labels, values)
plt.show()

# %%
colors = ['red', 'blue', 'green', 'yellow', 'purple']
plt.bar(labels, values, color = colors)
plt.show()

# %%
plt.plot(x,y, label = 'line 1')
plt.plot(y,x, label = 'Line 2')
plt.legend()
plt.show()

# %%
# Creating two line plots in one chart with legend
plt.plot(x, y, label='Line 1')
plt.plot(y, x, label='Line 2')
plt.legend()
plt.show()

# %%
import numpy as np

# %%
x = np.random.normal(4,6,100000)

# %%
plt.hist(x, bins = 200)
plt.axvline(x = 4, color = 'red', label = 'mean')
plt.show()

# %% [markdown]
# Creating Histogram

# %%
plt.hist(x)
plt.show()

# %%
y = [35, 25, 25, 15]

plt.pie(y)
plt.show()

# %%
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]


# Creating subplots
fig, axes = plt.subplots(nrows=2, ncols=2)

# Top-left plot (line plot)
axes[0, 0].plot(x, y)
axes[0, 0].set_title('Line Plot')

# Top-right plot (scatter plot)
axes[0, 1].scatter(x, y)
axes[0, 1].set_title('Scatter Plot')

# Bottom-left plot (bar plot)
labels = ['A', 'B', 'C', 'D', 'E']
values = [3, 7, 5, 2, 8]
axes[1, 0].bar(labels, values)
axes[1, 0].set_title('Bar Plot')

# Bottom-right plot (histogram)
x = np.random.normal(80, 5, 100)
axes[1, 1].hist(x)
axes[1, 1].set_title('Histogram')

# Adjust layout to prevent overlapping labels
plt.tight_layout()

# Show subplots
plt.show()
