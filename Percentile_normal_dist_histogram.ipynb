# %% [markdown]
# What is percentile:
# Percentile can be defined in 2 ways
# #1
# The total number of data points that are below the given or asked data point in the question is called “percentile”
#
# #2
# The total number of data points that are at and below the given or asked data point in the question is also considered as “percentile”

# %%
# HOW TO calucalte percentile in python
import numpy as np
dist = np.random.normal(loc = 5.0,size=10000)

# %%
# Find 55th percentile of the above data set

# %%
#find the 55th percentile of the array
np.percentile(dist, 55)
# Out:
# 5.12684652562591

# %%
np.percentile(dist, [25,50,75])
# Out:
# array([4.33519513, 5.00193431, 5.66549503])

# %%
# importing numpy for getting array
import numpy as np

# importing scientific python
from scipy import stats

# list of values
x = [10, 40, 20, 10, 30, 10, 56, 45]
dist = np.random.normal(loc=0.5,size=1000)

res = stats.cumfreq(dist, numbins=4
					)

# generating random values
rng = np.random.RandomState(seed=12345)

# normalizing
samples = stats.norm.rvs(size=1000,
						random_state=rng)

res = stats.cumfreq(samples,
					numbins=20)

x = res.lowerlimit + np.linspace(0, res.binsize*res.cumcount.size,
								res.cumcount.size)

fig = plt.figure(figsize=(10, 4))

ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.hist(samples, bins=25, color="green")

ax1.set_title('Histogram')
ax2.bar(x, x, width=2, color="blue")

ax2.set_title('Cumulative histogram')
ax2.set_xlim([x.min(), x.max()])

plt.show()
