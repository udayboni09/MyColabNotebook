# %%
import numpy as np
x = np.array([[0, 2], [2, 6], [1, 4], [2,5], [-1,-1]])

# %%
print(x)
# Out:
# [[ 0  2]
#  [ 2  6]
#  [ 1  4]
#  [ 2  5]
#  [-1 -1]]

# %%
np.cov(x)
# Out:
# array([[2. , 4. , 3. , 3. , 0. ],
#        [4. , 8. , 6. , 6. , 0. ],
#        [3. , 6. , 4.5, 4.5, 0. ],
#        [3. , 6. , 4.5, 4.5, 0. ],
#        [0. , 0. , 0. , 0. , 0. ]])
