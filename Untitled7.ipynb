# %%
from sklearn import datasets
import numpy as np
iris = datasets.load_iris()
# iris = datasets.load_iris()
X = iris.data     #inputs
y = iris.target #output variable

print(y.size)
# Out:
# 150
