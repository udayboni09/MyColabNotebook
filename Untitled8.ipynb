# %%
import numpy as np

# %%
a = 1
for i in range(1,6):
     a = a*i
     print("i:", i)
     print("a:",a)
print(a)
# Out:
# i: 1
# a: 1
# i: 2
# a: 2
# i: 3
# a: 6
# i: 4
# a: 24
# i: 5
# a: 120
# 120

# %%
nums = [1,2,3,4]
nums[-2]
# Out:
# 3

# %%
alphabets = {'1':'A','2':'B','3': ['C','D','E']}
alphabets['3'][2]
# Out:
# 'E'

# %%
list = ["Great", 51, True, 46, "Hi"]
list[2:-1]
# Out:
# [True, 46]

# %%
list_mul = ['2','2','2']
list_mul*2
# Out:
# ['2', '2', '2', '2', '2', '2']

# %%
def fun(n):
    return n*n*n

# %%
fun(3)
# Out:
# 27

# %%
lmbda_cube = lambda n: n*n*n
lmbda_cube(3)
# Out:
# 27
